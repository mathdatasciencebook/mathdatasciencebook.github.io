# %%
from numpy import *
set_printoptions(legacy = '1.25')

v = array([1,2,3])
shape(v)

# %%
u = array([1,2,3,4,5])
v = array([6,7,8,9,10])
t = 0.7

u + v, t*u

# %%
a = array([1.0,-2.3,11.7])
b = array([a,a])
c = array([b,b,b,b])
d = array([a,b,c], dtype = 'object')

for arr in a, b, c, d: 
	print(arr, shape(arr), ndim(arr), size(arr))

# %%
u = array([1,2,3,4,5])
v = array([6,7,8,9,10])
w = array([11,12,13,14,15])

B = array([u,v,w])
shape(B)

# %%
A = column_stack([u,v,w])
shape(A)

# %%
A.T == B

# %%
vector = arange(15) + 1
vector.reshape((3,5)).T

# %%
a = array([1,6,11])
N = len(a)
a_row = a.reshape((1,N))

u = array([1,2,3,4,5])
d = len(u)
u_col = u.reshape((d,1))

shape(u), shape(u_col), shape(a), shape(a_row)

# %%
A = zeros((2,3))
B = ones((2,2))
C = array([[1,2],[3,4]])
D = B + C
E = 5 * C
F = eye(4)
A, B, C, D, E, F

# %%
 
from scipy.linalg import block_diag

A = diag([1,2,3,4])
B = block_diag(-1, ones((2, 2)), array([[5], [7], [5]]))
A, B

# %%
diag(diag(u)) ==  u,  diag(diag(B)), B
