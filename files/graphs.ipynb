# %%
from numpy import *

def kahn(A):
	order = empty(0, dtype = int)
	indegree = sum(A, axis = 1)
	# inputs are nodes with zero indegree
	inputs = where(indegree == 0)[0]
	while len(inputs):
		# append inputs to order
		order = append(order,inputs)
		# delete edges outgoing from inputs
		for j in inputs: indegree[ A[:,j] != 0 ] -= 1
		not_in_order = full(len(A),True)
		not_in_order[order] = False
		# exclude inputs already in order
		inputs = where((indegree == 0) & not_in_order)[0]
	if len(A) == len(order): 
		return A[ meshgrid(order,order) ].T
	else: print('Graph is not a DAG')
	
A = zeros((8,8), dtype = int)
A[4,5] = A[4,3] = A[2,5] = A[2,3] = A[6,4] = 1
A[5,1] = A[3,1] = A[5,0] = A[3,0] = A[7,2] = 1

A, kahn(A)
