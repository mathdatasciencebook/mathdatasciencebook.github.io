# %%
from numpy import *
set_printoptions(legacy = '1.25')
	
from numpy.linalg import pinv
	
# projection of  vector v
# onto column space of A
	
def project(A, v):
	Aminus = pinv(A)
	x = dot(Aminus, v)    # reduced
	return dot(A, x)     # projected
