# %%
from numpy import *
set_printoptions(legacy = '1.25')

A = array([[1,2],[3,4]])
x = array([5,6])
b = dot(A,x)

shape(A) == (len(b), len(x))

# %%
from numpy.linalg import inv

# solving Ax = b
x = dot(inv(A), b)
x

# %%
# vectors
u = array([1,2,3,4,5])
v = array([6,7,8,9,10])
w = array([11,12,13,14,15])
	
# arrange as columns
A = column_stack([u,v,w])

# %%
from numpy.linalg import pinv

Aminus = pinv(A)

round(Aminus, 2), round(150*Aminus, 2)
