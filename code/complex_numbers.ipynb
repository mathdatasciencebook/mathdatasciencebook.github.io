# %%
from sympy import solve, symbols

z = symbols('z')

d = 5
solve(z**d - 1)

# %%
from numpy import *
	
# cube roots of unity

roots([1,0,0,-1])

# %%
array([-0.5+0.8660254j, -0.5-0.8660254j, 1. +0.j ])

# %%
from sympy import prod, solve, symbols, simplify
	
z = symbols('z')	
d = 5
roots = solve(z**d - 1)
	
p = prod([ 1-a if a != 1 else 1 for a in roots ])
simplify(p)
