# %%
from numpy import *

def factorial(n):
	if n == 1: return 1
	else: return n * factorial(n-1)
	
def stirling(n): return sqrt(2*pi*n) * (n/e)**n
	
x = factorial(100)
y = stirling(100)
	
print(x/y, x-y)
